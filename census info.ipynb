# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series,DataFrame
# %matplotlib inline
sns.set_style("whitegrid")

# %%
a1=pd.ExcelFile("CensusInfoData1.xls")
a1

# %%
a2=a1.parse("Population")
a=a2

# %%
a1=a[6:41]
a1.head(10)
a1.index=a1["CensusInfo - Population"]
a2=a1.drop(["CensusInfo - Population"],axis=1)
states=a1.index
a1.head()
# Out:
#                              CensusInfo - Population Unnamed: 1  Unnamed: 2  \
# CensusInfo - Population
# Andaman & Nicobar Islands  Andaman & Nicobar Islands         43        46.0
# Andhra Pradesh                        Andhra Pradesh        277       308.0
# Arunachal Pradesh                  Arunachal Pradesh         13        17.0
# Assam                                          Assam        340       397.0
# Bihar                                          Bihar        881      1102.0
#
#                           Unnamed: 3   Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# CensusInfo - Population
# Andaman & Nicobar Islands     356152     379944.0     192972    202330.0
# Andhra Pradesh              76210007   84665533.0   38527413  42509881.0
# Arunachal Pradesh            1097968    1382611.0     579941    720232.0
# Assam                       26655528   31169272.0   13777037  15954927.0
# Bihar                       82998509  103804637.0   43243795  54185347.0
#
# ...

# %%
b1_c=["state","density_01","density_11","total_01","total_11","male_01","male_11","female_01","female_11","rural_tot01","rural_tot11",
     "urban_tot01","uraban_tot11","rural_f01","rural_f11","urban_f01","urban_f11","rural_m01","rural_m11","urban_m01","urban_m11",
     "t0601","t0611","m0601","m0611","f0601","f0611","r0601","r0611","u0601","u0611","rf0601","rf0611","uf0601","uf0611",
     "rm0601","rm0611","um0601","um0611","tsr01","tsr11","rsr01","rsr11","usr01","usr11",
     "t06sr01","t06sr11","r06sr01","r06sr11","u06sr01","u06sr11"]

# %%
a1["Unnamed: 3"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 3"].plot(kind="bar",figsize=(20,5),alpha=1)

# %%
a1["Unnamed: 3"].plot(kind="kde",figsize=(20,5),alpha=1)

# %%
a2["index"]=np.arange(35)
a21=a2[["index","Unnamed: 1","Unnamed: 2"]]
#a2["Unnamed: 1"].unstack.plot(figsize=(25,10),label=True,alpha=1)
p1=a21["Unnamed: 1"].values
p2=a21["Unnamed: 2"].values
p1
# Out:
# array(['43', '277', '13', '340', '881', 7900, '154', '449', 1413, '364',
#        '258', '478', '109', '100', '338', '276', '819', 1895, '196',
#        '315', '97', '103', '42', '120', 9340, '236', 2034, '484', '165',
#        '76', '480', '305', '690', '159', '903'], dtype=object)

# %%
i1=[]
for i in np.arange(len(p1)):
    i1=np.append(i1,int(p1[i]))

# %%
i3=[]
for i in np.arange(len(p2)):
    i3=np.append(i3,int(p2[i]))

# %%
s=[]
for i in np.arange(len(states)):
    s=np.append(s,states[i])
s
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'NCT of Delhi',
#        'Orissa', 'Pondicherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype='<U32')

# %%
#i1
i4=Series(i3,index=s)
i4.head()
# Out:
# Andaman & Nicobar Islands      46.0
# Andhra Pradesh                308.0
# Arunachal Pradesh              17.0
# Assam                         397.0
# Bihar                        1102.0
# dtype: float64

# %%
#i1
i2=Series(i1,index=s)
i2.head()
# Out:
# Andaman & Nicobar Islands     43.0
# Andhra Pradesh               277.0
# Arunachal Pradesh             13.0
# Assam                        340.0
# Bihar                        881.0
# dtype: float64

# %%
i2.plot(kind="bar",figsize=(20,5),alpha=1,color="brown")
#i2.plot(figsize=(25,10),alpha=1,label=None,color="red")

# %% [markdown]
# population density in 2001

# %%
i4.plot(kind="bar",figsize=(20,5),alpha=1,color="red",title="pop. density in 2011")

# %% [markdown]
# the population density in 2011

# %%
i2.plot(kind="bar",figsize=(20,5),alpha=0.5,color="yellow")
i4.plot(kind="bar",figsize=(20,5),alpha=0.5,color="red")
#i2.plot(figsize=(25,10),alpha=1,label=None,color="red")
#i4.plot(figsize=(25,10),alpha=1,label=None,color="green")

# %% [markdown]
# so clearly Delhi seems the most densly populated state, and then we have Chandigardh as the other  densly populated city...
#
# while even the increase in the density seems the higest in Delhi

# %%
i5=(i4-i2)
i5.plot(kind="bar",figsize=(20,5),alpha=1)

# %% [markdown]
# as expected the density in delhi has increased the maximum,but the increase in Daman and Diu is another note worty fact here

# %%
i2.plot(figsize=(25,10),alpha=1,label=None)
i4.plot(figsize=(25,10),label=True,alpha=1)
#i4.plot()
x_axis=Series(s).T
#plt.plot(x_axis)
#plt.suptitle("census")

# %%
sns.kdeplot(p1,shade=True)
sns.kdeplot(p2,shade=True)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
i=a21["Unnamed: 1"][2]

# %%
p12=Series(p2)
p11=Series(p1)
#plt.hist(p11,alpha=0.5)
plt.hist(p12,alpha=0.5)
# Out:
# (array([30.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([   17.,  1145.,  2273.,  3401.,  4529.,  5657.,  6785.,  7913.,
#          9041., 10169., 11297.]),
#  <a list of 10 Patch objects>)

# %%
a1["Unnamed: 3"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 3"].plot(kind="bar",figsize=(20,5),alpha=1,title=" population 2001")

# %% [markdown]
# population in 2001

# %%
a1["Unnamed: 4"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 4"].plot(kind="bar",figsize=(20,6),alpha=1,title="population 2011")

# %% [markdown]
# population in 2011

# %%
#a1["Unnamed: 4"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 4"].plot(kind="bar",figsize=(20,5),alpha=0.5)
#a1["Unnamed: 3"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 3"].plot(kind="bar",figsize=(20,5),alpha=0.5,title="comparision of population 2011-2001")

# %% [markdown]
# clearly uttar pradesh seems to have the higest increase in the population,while the same state has been the most populated state in the nation

# %%
i6=abs(a1["Unnamed: 3"]-a1["Unnamed: 4"])

# %%
i6.plot(figsize=(25,10),label=True,alpha=1)
i6.plot(kind="bar",figsize=(20,5),alpha=1,title="diff of population 2011-2001")

# %% [markdown]
# so uttar pradesh and bihar seems to have the higest gain in the population during the time interval of 2011 to 2001

# %%
i7=(i6/a1["Unnamed: 4"])*100

# %%
i7.plot(figsize=(25,10),label=True,alpha=1)
i7.plot(kind="bar",figsize=(20,5),alpha=1,title="percentage increase in population 2011-2001")

# %% [markdown]
# now the senario becomes quite intresting dadar and nagar haveli and daman and diu has been led to the higest percentage increase in th population

# %%
a1["Unnamed: 5"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 5"].plot(kind="bar",figsize=(20,5),alpha=0.5,title=" Male population 2001 vs total pop.")
a1["Unnamed: 3"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 3"].plot(kind="bar",figsize=(20,5),alpha=0.5)

# %%
a1.head(1)
# Out:
#                              CensusInfo - Population Unnamed: 1  Unnamed: 2  \
# CensusInfo - Population
# Andaman & Nicobar Islands  Andaman & Nicobar Islands         43        46.0
#
#                           Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# CensusInfo - Population
# Andaman & Nicobar Islands     356152    379944.0     192972    202330.0
#
#                           Unnamed: 7  Unnamed: 8 Unnamed: 9     ...      \
# CensusInfo - Population                                         ...
# Andaman & Nicobar Islands     163180    177614.0     239954     ...
#
#                            Unnamed: 41 Unnamed: 42  Unnamed: 43 Unnamed: 44  \
# CensusInfo - Population
# Andaman & Nicobar Islands          861       871.0          815       891.0
#
#                            Unnamed: 45 Unnamed: 46  Unnamed: 47 Unnamed: 48  \
# CensusInfo - Population
# Andaman & Nicobar Islands          957       966.0          966       975.0
#
# ...

# %%
a1["Unnamed: 6"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 6"].plot(kind="bar",figsize=(20,5),alpha=0.5,title=" Male population 2011 vs total pop.")
a1["Unnamed: 4"].plot(figsize=(25,10),label=True,alpha=1)
a1["Unnamed: 4"].plot(kind="bar",figsize=(20,5),alpha=0.5)

# %%
diff_men=(a1["Unnamed: 6"]-a1["Unnamed: 5"])

# %%
diff_men.plot(figsize=(25,10),label=True,alpha=1)
diff_men.plot(kind="bar",figsize=(20,5),alpha=1,title="increase of male population in 2011 to 2001")

# %%
diff_female=(a1["Unnamed: 8"]-a1["Unnamed: 7"])

# %%
diff_female.plot(figsize=(25,10),label=True,alpha=1)
diff_female.plot(kind="bar",figsize=(20,5),alpha=1,title="increase of female population in 2011 to 2001")

# %%
diff=(a1["Unnamed: 6"]-a1["Unnamed: 8"])

# %%
diff.plot(figsize=(25,10),label=True,alpha=1)
diff.plot(kind="bar",figsize=(20,5),alpha=1,title="diff of male and female pop 2011,an indicator to sex ratio ")

# %% [markdown]
# intrestingly kerala is the only state where the female population leads the male population in 2011,

# %%
"""



education india


"""
# Out:
# '\n\n\n\neducation india\n\n\n'

# %%
a1=pd.ExcelFile("CensusInfoData1.xls")
a1

# %%
a3=a1.parse("Education")
b=a3

# %%
b.head()
# Out:
#   CensusInfo - Education                 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0              Area Name  Literacy rate, 7+ yrs (%)         NaN        NaN
# 1                    NaN                      Total         NaN      Males
# 2                    NaN                       2001     2011.00       2001
# 3                    NaN                        NaN         NaN        NaN
# 4                  India                      64.84       74.04      75.26
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN    Females         NaN      Rural         NaN      Urban
# 2     2011.00       2001     2011.00       2001     2011.00       2001
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4       82.14      53.67       65.46      58.74       68.91      79.92
#
#        ...        Unnamed: 27   Unnamed: 28   Unnamed: 29   Unnamed: 30  \
# ...

# %%
b1=b[5:39]
ind=b1["CensusInfo - Education"]
b2=b1.drop("CensusInfo - Education",axis=1)
b2.index=ind

# %%
b2.head()
# Out:
#                           Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# CensusInfo - Education
# Andaman & Nicobar Islands      81.30       86.27      86.33       90.11
# Andhra Pradesh                 60.47       67.66      70.32       75.56
# Arunachal Pradesh              54.34       66.95      63.83       73.69
# Assam                          63.25       73.18      71.28       78.81
# Bihar                             47       63.82      59.68       73.39
#
#                           Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# CensusInfo - Education
# Andaman & Nicobar Islands      75.24       81.84      78.70       84.39
# Andhra Pradesh                 50.43       59.74      54.50       61.14
# Arunachal Pradesh              43.53       59.57      47.83       61.59
# Assam                          54.61       67.27      59.73       70.44
# Bihar                          33.12       53.33      43.92       61.83
#
# ...

# %%
b2["Unnamed: 1"]
i8=Series(b2["Unnamed: 1"],index=s)
i8.head()
# Out:
# Andaman & Nicobar Islands    81.30
# Andhra Pradesh               60.47
# Arunachal Pradesh            54.34
# Assam                        63.25
# Bihar                           47
# Name: Unnamed: 1, dtype: object

# %%
type(i8["Andaman & Nicobar Islands"])
# Out:
# str

# %%
j8=[]
for i in  i8:
    j8=np.append(j8,float(i))

# %%
i8=j8

# %%
DataFrame(i8)[0].plot(kind="bar",figsize=(20,5),alpha=1,title="litracy rate 2001")

# %%
b1=a1
(b1.columns)=(b1_c)
